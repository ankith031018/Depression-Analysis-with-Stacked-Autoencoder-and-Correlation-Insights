# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('Student Depression Dataset.csv')
df.sample(4)
# Out:
#            id Gender   Age       City Profession  Academic Pressure  \
# 9850    49664   Male  30.0  Ahmedabad    Student                3.0
# 22810  115031   Male  19.0      Delhi    Student                1.0
# 3196    16099   Male  33.0     Rajkot    Student                3.0
# 16330   82611   Male  27.0     Mumbai    Student                5.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 9850             0.0  7.07                 1.0               0.0
# 22810            0.0  8.44                 4.0               0.0
# 3196             0.0  6.86                 5.0               0.0
# 16330            0.0  8.25                 3.0               0.0
#
#           Sleep Duration Dietary Habits    Degree  \
# 9850           7-8 hours        Healthy       MSc
# 22810  More than 8 hours        Healthy  Class 12
# 3196           7-8 hours        Healthy       BSc
# 16330          5-6 hours      Unhealthy       MBA
#
# ...

# %%
# Replace 'Male' with 0 and 'Female' with 1
df['Gender'].replace({'Male': 0, 'Female': 1},inplace=True)
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_6600\2863643261.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].replace({'Male': 0, 'Female': 1},inplace=True)
# C:\Users\ankit\AppData\Local\Temp\ipykernel_6600\2863643261.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
    df.sample(4)
# Out:
#            id  Gender   Age      City Profession  Academic Pressure  \
# 3703    18557       1  32.0  Ludhiana    Student                3.0
# 10693   54133       1  20.0    Kanpur    Student                5.0
# 2577    13134       0  30.0     Surat    Student                3.0
# 27348  137889       0  26.0    Rajkot    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 3703             0.0  7.77                 2.0               0.0
# 10693            0.0  5.64                 3.0               0.0
# 2577             0.0  7.71                 4.0               0.0
# 27348            0.0  8.54                 2.0               0.0
#
#           Sleep Duration Dietary Habits    Degree  \
# 3703           5-6 hours       Moderate    B.Tech
# 10693          7-8 hours      Unhealthy  Class 12
# 2577   Less than 5 hours       Moderate     M.Com
# 27348  Less than 5 hours      Unhealthy       BBA
#
# ...

# %%
# Replace 'Male' with 0 and 'Female' with 1
df['Have you ever had suicidal thoughts ?'].replace({'No': 0, 'Yes': 1},inplace=True)
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_6600\502690835.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Have you ever had suicidal thoughts ?'].replace({'No': 0, 'Yes': 1},inplace=True)
# ...

# %%
df.sample(4)
# Out:
#           id  Gender   Age       City Profession  Academic Pressure  \
# 4142   20723       1  30.0    Lucknow    Student                1.0
# 18008  91160       0  23.0      Delhi    Student                5.0
# 7311   36816       1  32.0  Hyderabad    Student                5.0
# 9993   50520       0  25.0   Srinagar    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 4142             0.0  7.92                 2.0               0.0
# 18008            0.0  6.89                 3.0               0.0
# 7311             0.0  8.08                 1.0               0.0
# 9993             0.0  8.25                 3.0               0.0
#
#       Sleep Duration Dietary Habits  Degree  \
# 4142       5-6 hours        Healthy     BHM
# 18008      7-8 hours      Unhealthy  B.Tech
# 7311       5-6 hours      Unhealthy      MD
# 9993       5-6 hours      Unhealthy      MA
#
#        Have you ever had suicidal thoughts ?  Work/Study Hours  \
# ...

# %%
df.drop('City', axis='columns', inplace=True)

# %%
df.sample(4)
# Out:
#            id  Gender   Age Profession  Academic Pressure  Work Pressure  \
# 11281   57127       1  20.0    Student                3.0            0.0
# 14567   73547       0  24.0    Student                4.0            0.0
# 6545    32834       0  30.0    Student                2.0            0.0
# 20691  104658       0  29.0    Student                4.0            0.0
#
#        CGPA  Study Satisfaction  Job Satisfaction     Sleep Duration  \
# 11281  8.49                 3.0               0.0          5-6 hours
# 14567  7.77                 2.0               0.0  Less than 5 hours
# 6545   7.27                 1.0               0.0  More than 8 hours
# 20691  6.86                 3.0               0.0  More than 8 hours
#
#       Dietary Habits    Degree  Have you ever had suicidal thoughts ?  \
# 11281       Moderate  Class 12                                      1
# 14567       Moderate    B.Tech                                      1
# ...

# %%
df.drop('id', axis='columns', inplace=True)

# %%
df.sample(3)
# Out:
#        Gender   Age Profession  Academic Pressure  Work Pressure  CGPA  \
# 22860       1  28.0    Student                1.0            0.0  8.25
# 12488       1  34.0    Student                4.0            0.0  7.09
# 15467       1  32.0    Student                4.0            0.0  9.79
#
#        Study Satisfaction  Job Satisfaction     Sleep Duration Dietary Habits  \
# 22860                 3.0               0.0          7-8 hours        Healthy
# 12488                 1.0               0.0  Less than 5 hours        Healthy
# 15467                 3.0               0.0          5-6 hours       Moderate
#
#       Degree  Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 22860   M.Ed                                      1               6.0
# 12488   MBBS                                      1               8.0
# 15467    MBA                                      1               3.0
#
#        Financial Stress Family History of Mental Illness  Depression
# ...

# %%
df['Family History of Mental Illness'].replace({'No': 0, 'Yes': 1},inplace=True)
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_6600\674481413.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Family History of Mental Illness'].replace({'No': 0, 'Yes': 1},inplace=True)
# ...

# %%
df.dtypes
# Out:
# Gender                                     int64
# Age                                      float64
# Profession                                object
# Academic Pressure                        float64
# Work Pressure                            float64
# CGPA                                     float64
# Study Satisfaction                       float64
# Job Satisfaction                         float64
# Sleep Duration                            object
# Dietary Habits                            object
# Degree                                    object
# Have you ever had suicidal thoughts ?      int64
# Work/Study Hours                         float64
# Financial Stress                         float64
# Family History of Mental Illness           int64
# Depression                                 int64
# dtype: object

# %%
for col in df:
    print (f'{col} : {df[col].unique()}')
# Out:
# Gender : [0 1]
# Age : [33. 24. 31. 28. 25. 29. 30. 27. 19. 20. 23. 18. 21. 22. 34. 32. 26. 39.
#  35. 42. 36. 58. 49. 38. 51. 44. 43. 46. 59. 54. 48. 56. 37. 41.]
# Profession : ['Student' 'Civil Engineer' 'Architect' 'UX/UI Designer'
#  'Digital Marketer' 'Content Writer' 'Educational Consultant' 'Teacher'
#  'Manager' 'Chef' 'Doctor' 'Lawyer' 'Entrepreneur' 'Pharmacist']
# Academic Pressure : [5. 2. 3. 4. 1. 0.]
# Work Pressure : [0. 5. 2.]
# CGPA : [ 8.97    5.9     7.03    5.59    8.13    5.7     9.54    8.04    9.79
#   8.38    6.1     7.04    8.52    5.64    8.58    6.51    7.25    7.83
#   9.93    8.74    6.73    5.57    8.59    7.1     6.08    5.74    9.86
#   6.7     6.21    5.87    6.37    9.72    5.88    9.56    6.99    5.24
#   9.21    7.85    6.95    5.86    7.92    9.66    8.94    9.71    7.87
#   5.6     7.9     5.46    6.79    8.7     7.38    8.5     7.09    9.82
#   8.89    7.94    9.11    6.75    7.53    9.49    9.01    7.64    5.27
# ...

# %%
# Display the Profession and Depression columns as a table
df[['Profession', 'Depression']].sample(10)
# Out:
#       Profession  Depression
# 6512     Student           1
# 1549     Student           0
# 15297    Student           0
# 20222    Student           1
# 5939     Student           0
# 11548    Student           1
# 20547    Student           1
# 14298    Student           1
# 6340     Student           0
# 6469     Student           0

# %%
average_cgpa = df.groupby('Depression')['CGPA']

# %%
plt.figure(figsize=(8, 5))
average_cgpa.plot(kind='bar', color=['salmon', 'skyblue'])
plt.xticks(ticks=[0, 1], labels=['No Depression', 'Depression'], rotation=0)
plt.title('Average CGPA of Students with Respect to Depression Status')
plt.xlabel('Depression Status')
plt.ylabel('Average CGPA')
plt.grid(axis='y')

plt.show()

# %%
average_cgpa.sample(4)
# Out:
# 10271    6.38
# 12976    7.82
# 7749     5.46
# 2531     9.63
# 19196    7.88
# 9702     7.83
# 3927     5.16
# 13962    9.63
# Name: CGPA, dtype: float64

# %%
df.sample(4)
# Out:
#        Gender   Age Profession  Academic Pressure  Work Pressure  CGPA  \
# 8064        1  24.0    Student                1.0            0.0  6.83
# 25342       0  23.0    Student                5.0            0.0  8.04
# 16207       1  27.0    Student                4.0            0.0  5.59
# 5816        1  20.0    Student                3.0            0.0  7.00
#
#        Study Satisfaction  Job Satisfaction     Sleep Duration Dietary Habits  \
# 8064                  3.0               0.0          5-6 hours      Unhealthy
# 25342                 4.0               0.0  Less than 5 hours      Unhealthy
# 16207                 5.0               0.0          5-6 hours       Moderate
# 5816                  3.0               0.0          5-6 hours        Healthy
#
#       Degree  Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 8064     MBA                                      0               7.0
# 25342   B.Ed                                      1              10.0
# ...

# %%
df.drop('Degree', axis='columns', inplace=True)

# %%
df.sample(4)
# Out:
#        Gender   Age Profession  Academic Pressure  Work Pressure  CGPA  \
# 6249        1  26.0    Student                2.0            0.0  5.30
# 3282        0  23.0    Student                1.0            0.0  8.53
# 6172        1  31.0    Student                5.0            0.0  8.40
# 15669       1  29.0    Student                4.0            0.0  5.88
#
#        Study Satisfaction  Job Satisfaction     Sleep Duration Dietary Habits  \
# 6249                  1.0               0.0  More than 8 hours       Moderate
# 3282                  4.0               0.0          7-8 hours      Unhealthy
# 6172                  1.0               0.0          5-6 hours       Moderate
# 15669                 1.0               0.0  More than 8 hours        Healthy
#
#        Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 6249                                       0              10.0
# 3282                                       0               4.0
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, MultiHeadAttention, Dropout, LayerNormalization

# %%
# Check for missing values and handle them if needed
df.fillna(method='ffill', inplace=True)

# Check column names
print("Original column names:", df.columns.tolist())

# Step 2: Strip whitespace from column names
df.columns = df.columns.str.strip()

# Verify the cleaned column names
print("Cleaned column names:", df.columns.tolist())
# Out:
# Original column names: ['Age', 'Academic Pressure', 'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction', 'Work/Study Hours', 'Financial Stress', 'Depression', 'Gender_0', 'Gender_1', 'Profession_Architect', 'Profession_Chef', 'Profession_Civil Engineer', 'Profession_Content Writer', 'Profession_Digital Marketer', 'Profession_Doctor', 'Profession_Educational Consultant', 'Profession_Entrepreneur', 'Profession_Lawyer', 'Profession_Manager', 'Profession_Pharmacist', 'Profession_Student', 'Profession_Teacher', 'Profession_UX/UI Designer', 'Sleep Duration_5-6 hours', 'Sleep Duration_7-8 hours', 'Sleep Duration_Less than 5 hours', 'Sleep Duration_More than 8 hours', 'Sleep Duration_Others', 'Dietary Habits_Healthy', 'Dietary Habits_Moderate', 'Dietary Habits_Others', 'Dietary Habits_Unhealthy', 'Have you ever had suicidal thoughts ?_0', 'Have you ever had suicidal thoughts ?_1', 'Family History of Mental Illness_0', 'Family History of Mental Illness_1']
# ...

# %%
# One-Hot Encoding
# Select categorical columns for one-hot encoding
categorical_cols = ['Gender', 'Profession', 'Sleep Duration', 'Dietary Habits', 
                    'Have you ever had suicidal thoughts ?', 'Family History of Mental Illness']

# Check if all categorical columns exist in the DataFrame
missing_cols = [col for col in categorical_cols if col not in df.columns]
if missing_cols:
    print(f"Missing columns: {missing_cols}")
else:
    # Apply one-hot encoding
    encoder = OneHotEncoder(sparse_output=False)  # Use sparse_output instead of sparse
    encoded_features = encoder.fit_transform(df[categorical_cols])

    # Convert encoded features to DataFrame and concatenate with original DataFrame
    encoded_df = pd.DataFrame(encoded_features, columns=encoder.get_feature_names_out(categorical_cols))
    df = pd.concat([df.drop(columns=categorical_cols), encoded_df], axis=1)
# Out:
# Missing columns: ['Gender', 'Profession', 'Sleep Duration', 'Dietary Habits', 'Have you ever had suicidal thoughts ?', 'Family History of Mental Illness']

# %%
encoded_df.sample(4)
# Out:
#        Gender_0  Gender_1  Profession_Architect  Profession_Chef  \
# 4022        1.0       0.0                   0.0              0.0
# 5049        1.0       0.0                   0.0              0.0
# 216         1.0       0.0                   0.0              0.0
# 18203       1.0       0.0                   0.0              0.0
#
#        Profession_Civil Engineer  Profession_Content Writer  \
# 4022                         0.0                        0.0
# 5049                         0.0                        0.0
# 216                          0.0                        0.0
# 18203                        0.0                        0.0
#
#        Profession_Digital Marketer  Profession_Doctor  \
# 4022                           0.0                0.0
# 5049                           0.0                0.0
# 216                            0.0                0.0
# 18203                          0.0                0.0
#
# ...

# %%
encoded_df.iloc[4022]
# Out:
# Gender_0                                   1.0
# Gender_1                                   0.0
# Profession_Architect                       0.0
# Profession_Chef                            0.0
# Profession_Civil Engineer                  0.0
# Profession_Content Writer                  0.0
# Profession_Digital Marketer                0.0
# Profession_Doctor                          0.0
# Profession_Educational Consultant          0.0
# Profession_Entrepreneur                    0.0
# Profession_Lawyer                          0.0
# Profession_Manager                         0.0
# Profession_Pharmacist                      0.0
# Profession_Student                         1.0
# Profession_Teacher                         0.0
# Profession_UX/UI Designer                  0.0
# Sleep Duration_5-6 hours                   0.0
# Sleep Duration_7-8 hours                   1.0
# Sleep Duration_Less than 5 hours           0.0
# Sleep Duration_More than 8 hours           0.0
# ...

# %%
encoded_df.dtypes
# Out:
# Gender_0                                   float64
# Gender_1                                   float64
# Profession_Architect                       float64
# Profession_Chef                            float64
# Profession_Civil Engineer                  float64
# Profession_Content Writer                  float64
# Profession_Digital Marketer                float64
# Profession_Doctor                          float64
# Profession_Educational Consultant          float64
# Profession_Entrepreneur                    float64
# Profession_Lawyer                          float64
# Profession_Manager                         float64
# Profession_Pharmacist                      float64
# Profession_Student                         float64
# Profession_Teacher                         float64
# Profession_UX/UI Designer                  float64
# Sleep Duration_5-6 hours                   float64
# Sleep Duration_7-8 hours                   float64
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt
import torch
from torch import nn, optim
from torch.utils.data import DataLoader, TensorDataset

# %%
df.fillna(df.median(numeric_only=True), inplace=True)

# Calculate correlation matrix to find relationships with 'depression'
correlation_matrix = df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Identify and print highly correlated features for depression
correlated_features = correlation_matrix['Depression'].sort_values(ascending=False)
print("Features correlated with depression:")
print(correlated_features)
# Out:
# Features correlated with depression:
# Depression                                 1.000000
# Have you ever had suicidal thoughts ?_1    0.546277
# Academic Pressure                          0.474835
# Financial Stress                           0.363543
# Work/Study Hours                           0.208563
# Dietary Habits_Unhealthy                   0.189352
# Sleep Duration_Less than 5 hours           0.078830
# Family History of Mental Illness_1         0.053430
# CGPA                                       0.022210
# Sleep Duration_7-8 hours                   0.011551
# Profession_Architect                       0.009952
# Profession_Teacher                         0.007378
# Profession_Pharmacist                      0.007124
# Profession_Content Writer                  0.007124
# Profession_Doctor                          0.007124
# Profession_Chef                            0.007124
# Profession_Entrepreneur                    0.005037
# ...

# %%
# One-Hot Encoding for categorical features
categorical_columns = df.select_dtypes(include=['object']).columns
encoder = OneHotEncoder(sparse_output=False)
encoded_columns = encoder.fit_transform(df[categorical_columns])
encoded_df = pd.DataFrame(encoded_columns, columns=encoder.get_feature_names_out(categorical_columns))

# %%
# Drop original categorical columns and concatenate encoded columns
df = df.drop(categorical_columns, axis=1)
df = pd.concat([df, encoded_df], axis=1)

# %%
X = df.drop('Depression', axis=1)
y = df['Depression']

# %%
# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
# Define a stacked autoencoder model
class StackedAutoencoder(nn.Module):
    def __init__(self, input_size):
        super(StackedAutoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 32)
        )
        self.decoder = nn.Sequential(
            nn.Linear(32, 64),
            nn.ReLU(),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128, input_size)
        )

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return encoded, decoded

# %%
# Initialize autoencoder model
input_size = X_train.shape[1]
model = StackedAutoencoder(input_size)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Convert data to tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.float32)

# %%
# Train autoencoder
train_loader = DataLoader(TensorDataset(X_train_tensor, X_train_tensor), batch_size=32, shuffle=True)
epochs = 20
for epoch in range(epochs):
    for batch_features, _ in train_loader:
        encoded, decoded = model(batch_features)
        loss = criterion(decoded, batch_features)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f"Epoch {epoch+1}, Loss: {loss.item()}")

# Use encoded features for classification
encoded_X_train = model.encoder(X_train_tensor)
encoded_X_test = model.encoder(X_test_tensor)
# Out:
# Epoch 1, Loss: 0.020936517044901848
# Epoch 2, Loss: 0.0024464167654514313
# Epoch 3, Loss: 0.0016988290008157492
# Epoch 4, Loss: 0.003491913201287389
# Epoch 5, Loss: 0.004548860248178244
# Epoch 6, Loss: 0.004595818929374218
# Epoch 7, Loss: 0.0031919756438583136
# Epoch 8, Loss: 0.0014258601004257798
# Epoch 9, Loss: 0.003213103162124753
# Epoch 10, Loss: 0.0024569444358348846
# Epoch 11, Loss: 0.0005620770971290767
# Epoch 12, Loss: 0.001320010982453823
# Epoch 13, Loss: 0.000514591985847801
# Epoch 14, Loss: 0.0011796848848462105
# Epoch 15, Loss: 0.02615407668054104
# Epoch 16, Loss: 0.004331411328166723
# Epoch 17, Loss: 0.0019039255566895008
# Epoch 18, Loss: 0.0018411945784464478
# Epoch 19, Loss: 0.3477587401866913
# Epoch 20, Loss: 0.0016819434240460396

# %%
# Example classifier (logistic regression or other models can be plugged in)
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(encoded_X_train.detach().numpy(), y_train)
accuracy = classifier.score(encoded_X_test.detach().numpy(), y_test)
print(f"Classification Accuracy using Stacked Autoencoder features: {accuracy}")
# Out:
# Classification Accuracy using Stacked Autoencoder features: 0.8376635011646658
# C:\Users\ankit\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
